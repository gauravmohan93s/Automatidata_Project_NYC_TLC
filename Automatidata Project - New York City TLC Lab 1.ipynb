# %% [markdown]
# ### Automatidata Project for New York City Taxi and Limousine Commission (TLC)
#
# #### Project Overview
# Automatidata has partnered with the New York City Taxi and Limousine Commission (TLC) to develop a regression model that estimates taxi fares before the ride, using data gathered by TLC. The dataset includes information from over 200,000 taxi and limousine licensees, who make approximately one million combined trips per day. This project is in its initial stages, and a structured plan is essential for its successful execution.
#
# #### Project Goals
# 1. Develop a regression model to estimate taxi fares.
# 2. Provide strategic business insights based on the TLC data.
# 3. Create visual aids for TLC executives to demonstrate project progress and results.
#
# #### Key Stakeholders
# - **Automatidata Team Members:**
#   - Udo Bankole, Director of Data Analysis
#   - Deshawn Washington, Data Analysis Manager
#   - Luana Rodriquez, Senior Data Analyst
#   - Uli King, Senior Project Manager
#
# - **New York City TLC Team Members:**
#   - Juliana Soto, Finance and Administration Department Head
#   - Titus Nelson, Operations Manager

# %% [markdown]
# ### Automatidata Project Deliverables for New York City TLC
#
# #### Project Deliverables
#
# 1. **PACE Strategy Document**
#    - **Purpose:** Plan the project by considering the audience members, teammates, key milestones, and overall project goal.
#    - **Components:**
#      - **Planning:**
#        - Identify stakeholders and their roles.
#        - Outline project goals and deliverables.
#        - Define key milestones and timelines.
#      - **Analysis:**
#        - Inspect and clean the dataset.
#        - Conduct exploratory data analysis (EDA).
#      - **Creation:**
#        - Develop and validate the regression model.
#        - Test and refine the model.
#      - **Execution:**
#        - Prepare and deliver the final presentation to TLC stakeholders.
#        - Provide recommendations for future improvements.

# %% [markdown]
# ![image.png](attachment:d9c55f1a-11cd-4789-ae54-56dfc5854ff2.png)

# %% [markdown]
# 2. **Project Proposal for the Data Team**
#    - **Purpose:** Guide the data team through the project, detailing tasks, milestones, and stakeholder interactions.
#    - **Components:**
#      - **Introduction:**
#        - Background on the TLC project and its goals.
#        - Overview of Automatidata's
#
# #### Project Tasks and Milestones
# ##### PACE Workflow
# - **Planning**
#   - **Milestone 1:** Initial Project Setup and Planning
#     - Task 1: Review project requirements and meeting notes.
#     - Task 2: Outline project goals and deliverables.
#     - Task 3: Identify stakeholders and their roles.
#
# - **Analysis**
#   - **Milestone 2:** Data Inspection and Cleaning
#     - Task 4: Inspect and clean the TLC dataset.
#     - Task 5: Document data quality issues and address them.
#     - Task 6: Perform exploratory data analysis (EDA) to understand data distributions and relationships.
#
#   - **Milestone 3:** Exploratory Data Analysis (EDA)
#     - Task 7: Generate summary statistics and visualizations.
#     - Task 8: Identify key variables and potential predictors for the regression model.
#     - Task 9: Present EDA findings to the team.
#
# - **Creation**
#   - **Milestone 4:** Model Development
#     - Task 10: Split the data into training and testing sets.
#     - Task 11: Develop initial regression models using Python.
#     - Task 12: Evaluate model performance and refine as needed.
#     - Task 13: Conduct A/B testing to validate model assumptions and relationships between variables.
#
#   - **Milestone 5:** Model Validation and Testing
#     - Task 14: Validate the final regression model against the test dataset.
#     - Task 15: Ensure the model meets the project requirements and performance criteria.
#     - Task 16: Document model validation process and results.
#
# - **Execution**
#   - **Milestone 6:** Presentation and Delivery
#     - Task 17: Prepare presentation materials and visuals for TLC executives.
#     - Task 18: Summarize key insights and model performance.
#     - Task 19: Deliver the final presentation to TLC stakeholders.
#     - Task 20: Provide recommendations for future improvements and potential applications of the model.
#
# **Stakeholder Communication:**
# - Detailed communication plan tailored to technical and non-technical stakeholders.
# - Regular updates and checkpoints with the team and TLC representatives.
#
# By following this structured approach, Automatidata aims to deliver a robust and accurate regression model that meets the TLC's needs and supports informed decision-making within their operations.

# %% [markdown]
# #### Detailed Deliverable Breakdown
#
# 1. **PACE Strategy Document**
#    - **Audience Members:**
#      - Automatidata team members (technical)
#      - TLC stakeholders (non-technical)
#    - **Teammates:**
#      - Udo Bankole, Director of Data Analysis
#      - Deshawn Washington, Data Analysis Manager
#      - Luana Rodriquez, Senior Data Analyst
#      - Uli King, Senior Project Manager
#    - **Key Milestones:**
#      - Project Setup and Planning
#      - Data Inspection and Cleaning
#      - Exploratory Data Analysis (EDA)
#      - Model Development
#      - Model Validation and Testing
#      - Presentation and Delivery
#    - **Overall Project Goal:**
#      - Develop a regression model to estimate taxi fares before the ride, using TLC's dataset.
#
# 2. **Project Proposal for the Data Team**
#    - **Project Background:**
#      - Description of the TLC project and Automatidata’s consulting role.
#    - **Milestones and Tasks:**
#      - Clear and detailed tasks under each milestone.
#      - Timeframes and dependencies.
#    - **Communication Plan:**
#      - Regular updates and meeting schedules.
#      - Tailored communication for technical and non-technical stakeholders.
#    - **Expected Outcomes:**
#      - A reliable regression model for estimating taxi fares.
#      - Strategic insights and visual aids for TLC executives.
#      - Recommendations for future improvements based on data analysis.

# %% [markdown]
# # **Automatidata project**
# **Course 2 - Get Started with Python**

# %% [markdown]
# ![image.png](attachment:f601a7ac-0cb5-4252-902d-519d9baa2d5a.png)

# %% [markdown]
# # Course 2 End-of-course project: Inspect and analyze data
#
# In this activity, you will examine data provided and prepare it for analysis.  This activity will help ensure the information is,
#
# 1.   Ready to answer questions and yield insights
#
# 2.   Ready for visualizations
#
# 3.   Ready for future hypothesis testing and statistical methods
# <br/>
#
# **The purpose** of this project is to investigate and understand the data provided.
#
# **The goal** is to use a dataframe contructed within Python, perform a cursory inspection of the provided dataset, and inform team members of your findings.
# <br/>
# *This activity has three parts:*
#
# **Part 1:** Understand the situation
# * Prepare to understand and organize the provided taxi cab dataset and information.
#
# **Part 2:** Understand the data
#
# * Create a pandas dataframe for data learning, future exploratory data analysis (EDA), and statistical activities.
#
# * Compile summary information about the data to inform next steps.
#
# **Part 3:** Understand the variables
#
# * Use insights from your examination of the summary data to guide deeper investigation into specific variables.

# %% [markdown]
# # **Identify data types and relevant variables using Python**

# %% [markdown]
# <img src="images/Pace.png" width="100" height="100" align=left>
#
# # **PACE stages**

# %% [markdown]
# Throughout these project notebooks, you'll see references to the problem-solving framework PACE. The following notebook components are labeled with the respective PACE stage: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## PACE: **Plan**
#
# Consider the questions in your PACE Strategy Document and those below to craft your response:

# %% [markdown]
# ### **Task 1. Understand the situation**
#
# *   How can you best prepare to understand and organize the provided taxi cab information?
# * Begin by exploring your dataset and consider reviewing the Data Dictionary. One can prepare to understand the information by reading the taxi cab data fields and understanding the impact of each one. Reviewing the fact sheet could also provide helpful background information. However, the primary goal is to get the data into Python, inspect it, and provide DeShawn with initial observations. The next step would be to learn more about the data and check for any anomalies.

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# ## PACE: **Analyze**
#
# Consider the questions in your PACE Strategy Document to reflect on the Analyze stage.

# %% [markdown]
# ### **Task 2a. Build dataframe**

# %% [markdown]
# Create a pandas dataframe for data learning, and future exploratory data analysis (EDA) and statistical activities.

# %%
#Import libraries and packages
import pandas as pd
import numpy as np

# Load dataset into dataframe
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')
print("done")
# Out:
# done

# %% [markdown]
# ### **Task 2b. Understand the data - Inspect the data**
#
# View and inspect summary information about the dataframe by coding the following:
#
# 1. `df.head(10)`
# 2. `df.info()`
# 3. `df.describe()`
#
# Consider the following two questions:
#
# **Question 1:** When reviewing the `df.info()` output, what do you notice about the different variables? Are there any null values? Are all of the variables numeric? Does anything else stand out?
#
# **Question 2:** When reviewing the `df.describe()` output, what do you notice about the distributions of each variable? Are there any questionable values?

# %%
#inspecting data by visualising first 10 row in dataset
df.head(10)
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5    23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6    37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7    69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8     8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9    95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# ...

# %%
#inspecting data by info method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %% [markdown]
# **Question 1:** Dtypes are non-numeric. Two of which are datetime.
# No null values.

# %%
#inspecting data by describe method
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %% [markdown]
# **Question 2:** Regarding fare amount, the distribution is worth considering. The maximum fare amount is a much larger value ($1000) than the 25-75 percent range of values. Also, it's questionable how there are negative values for fare amount. Regarding trip distance, most rides are between 1-3 miles, but the maximum is over 33 miles.

# %% [markdown]
# ### **Task 2c. Understand the data - Investigate the variables**
#
# Sort and interpret the data table for two variables:`trip_distance` and `total_amount`.
#
# **Answer the following three questions:**
#
# **Question 1:** Sort your first variable (`trip_distance`) from maximum to minimum value, do the values seem normal?
#
# **Question 2:** Sort by your second variable (`total_amount`), are any values unusual?
#
# **Question 3:** Are the resulting rows similar for both sorts? Why or why not?

# %%
# Sort the data by trip distance from maximum to minimum value

df_sort = df.sort_values(by=['trip_distance'],ascending=False)
df_sort.head(10)
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 9280     51810714         2  06/18/2017 11:33:25 PM  06/19/2017 12:12:38 AM
# 13861    40523668         2   05/19/2017 8:20:21 AM   05/19/2017 9:20:30 AM
# 6064     49894023         2  06/13/2017 12:30:22 PM   06/13/2017 1:37:51 PM
# 10291    76319330         2  09/11/2017 11:41:04 AM  09/11/2017 12:18:58 PM
# 29       94052446         2   11/06/2017 8:30:50 PM  11/07/2017 12:00:00 AM
# 18130    90375786         1   10/26/2017 2:45:01 PM   10/26/2017 4:12:49 PM
# 5792     68023798         2   08/11/2017 2:14:01 PM   08/11/2017 3:17:31 PM
# 15350    77309977         2   09/14/2017 1:44:44 PM   09/14/2017 2:34:29 PM
# 10302    43431843         1   05/15/2017 8:11:34 AM   05/15/2017 9:03:16 AM
# 2592     51094874         2   06/16/2017 6:51:20 PM   06/16/2017 7:41:42 PM
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %% [markdown]
# **Question 1:**  The values align with our earlier data discovery, where we noticed that the longest rides are approximately 33 miles.

# %%
# Sort the data by total amount and print the top 20 values
total_amount_sorted = df.sort_values(['total_amount'],ascending=False)['total_amount']
total_amount_sorted.head(20)
# Out:
# 8476     1200.29
# 20312     450.30
# 13861     258.21
# 12511     233.74
# 15474     211.80
# 6064      179.06
# 16379     157.06
# 3582      152.30
# 11269     151.82
# 9280      150.30
# 1928      137.80
# 10291     131.80
# 6708      126.00
# 11608     123.30
# 908       121.56
# 7281      120.96
# 18130     119.31
# 13621     115.94
# 13359     111.95
# 29        111.38
# Name: total_amount, dtype: float64

# %% [markdown]
# **Question 2:** Yes, the first two values are significantly higher than the others.

# %%
# Sort the data by total amount and print the bottom 20 values
total_amount_sorted = df.sort_values(['total_amount'],ascending=False)['total_amount']
total_amount_sorted.tail(20)
# Out:
# 14283      0.31
# 19067      0.30
# 10506      0.00
# 5722       0.00
# 4402       0.00
# 22566      0.00
# 1646      -3.30
# 18565     -3.80
# 314       -3.80
# 5758      -3.80
# 5448      -4.30
# 4423      -4.30
# 10281     -4.30
# 8204      -4.80
# 20317     -4.80
# 11204     -5.30
# 14714     -5.30
# 17602     -5.80
# 20698     -5.80
# 12944   -120.30
# Name: total_amount, dtype: float64

# %% [markdown]
# **Question 3:** The most expensive rides are not necessarily the longest ones.

# %%
# How many of each payment type are represented in the data?
df['payment_type'].value_counts()
# Out:
# payment_type
# 1    15265
# 2     7267
# 3      121
# 4       46
# Name: count, dtype: int64

# %% [markdown]
# According to the data dictionary, the payment method was encoded as follows:
#
# 1 = Credit card
# 2 = Cash
# 3 = No charge
# 4 = Dispute
# 5 = Unknown
# 6 = Voided trip

# %%
# What is the average tip for trips paid for with credit card?

avg_cc_tip = df[df['payment_type']==1]['tip_amount'].mean()
print('Avg. CC tip:', avg_cc_tip)

# What is the average tip for trips paid for with cash?

avg_cash_tip = df[df['payment_type']==2]['tip_amount'].mean()
print('Avg. Cash tip:', avg_cash_tip)
# Out:
# Avg. CC tip: 2.7298001965280054
# Avg. Cash tip: 0.0

# %%
# How many times is each vendor ID represented in the data?
df['VendorID'].value_counts()
# Out:
# VendorID
# 2    12626
# 1    10073
# Name: count, dtype: int64

# %%
# What is the mean total amount for each vendor?
df.groupby('VendorID').mean(numeric_only=True)[['total_amount']]
# Out:
#           total_amount
# VendorID
# 1            16.298119
# 2            16.320382

# %%
# Filter the data for credit card payments only
credit_card = df[df['payment_type']==1]

# Filter the credit-card-only data for passenger count only
credit_card['passenger_count'].value_counts()
# Out:
# passenger_count
# 1    10977
# 2     2168
# 5      775
# 3      600
# 6      451
# 4      267
# 0       27
# Name: count, dtype: int64

# %%
# Calculate the average tip amount for each passenger count (credit card payments only)
credit_card.groupby('passenger_count').mean(numeric_only=True)[['tip_amount']]
# Out:
#                  tip_amount
# passenger_count
# 0                  2.610370
# 1                  2.714681
# 2                  2.829949
# 3                  2.726800
# 4                  2.607753
# 5                  2.762645
# 6                  2.643326

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## PACE: **Construct**
#
# **Note**: The Construct stage does not apply to this workflow. The PACE framework can be adapted to fit the specific requirements of any project.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## PACE: **Execute**
#
# Consider the questions in your PACE Strategy Document and those below to craft your response.

# %% [markdown]
# ### **Given your efforts, what can you summarize for DeShawn and the data team?**
#
# *Which two variables are most helpful for building a predictive model for the client: NYC TLC?*

# %% [markdown]
# After looking at the dataset, the two variables that are most likely to help build a predictive model for taxi ride fares are total_amount and trip_distance because those variables show a picture of a taxi cab ride.
